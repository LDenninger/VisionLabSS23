# %% [markdown]
# # Solutions Task 6

# %% [markdown]
# ## Imports

# %%
import torch
import torchgadgets as tg

# %% [markdown]
# ## Data

# %%
dataset = tg.data.load_dataset("food101")
train_dataset = dataset['train_dataset']
test_dataset = dataset['test_dataset']
fig = tg.visualization.visualize_dataset(train_dataset)
fig.show()

# %%
print('Length training dataset: '+str(len(train_dataset)))
print('Length training dataset: '+str(len(test_dataset)))
# Out:
# Length training dataset: 75750
# Length training dataset: 25250
