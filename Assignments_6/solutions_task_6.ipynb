# %% [markdown]
# # Solutions Task 6

# %% [markdown]
# ## Imports

# %%
import torch
import torchgadgets as tg

# %% [markdown]
# ## Data

# %%
dataset = tg.data.load_dataset("food101")
train_dataset = dataset['train_dataset']
test_dataset = dataset['test_dataset']
fig = tg.visualization.visualize_dataset(train_dataset)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 test_dataset = dataset['test_dataset']
#       4 fig = tg.visualization.visualize_dataset(train_dataset)
# ----> 5 fig.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'
